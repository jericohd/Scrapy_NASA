# %% [markdown]
# <a href="https://colab.research.google.com/github/jericohd/Scrapy_NASA/blob/main/Actividad_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 5**
# Preprocesamiento de datos
#
# ---

# %% [markdown]
# *   NOMBRE: Hernandez Diaz Irving Jerico
# *   MATRÍCULA: A01795534

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import os
#DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 5/Actividad5_Preprocesamiento"
#os.chdir(DIR)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
response_df = pd.read_csv('responses.csv')
response_df
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %% [markdown]
# 1. Determina cuántas variables numéricas y cuántas de texto posee el conjunto de datos con el método `info()` y utiliza el método `describe()` del dataframe, para obtener el resumen de las estadísticas descriptivas. Separa el análisis según el tipo de datos (number, object).

# %%
response_df.describe()
# Out:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# count  1005.000000      1003.000000  1008.000000  1007.000000  1004.000000
# mean      2.123383         2.956132     2.761905     3.471698     3.761952
# std       1.076136         1.252570     1.260845     1.161400     1.184861
# ...

# %% [markdown]
# 2. Clasifique la variable `Weight` según su escala de medición. En función de ello elija el gráfico a generar (histograma / barras) y fundamente su elección.

# %%
import matplotlib.pyplot as plt
# Histogram for Weight
plt.figure(figsize=(10, 6))
sns.histplot(data=response_df, x="Weight", kde=True)
plt.title("Distribution of Weight")
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 3. Clasifique la distribución del peso según su asimetría, justificando tu respuesta. Incluye el cálculo numérico que lo demuestra.

# %%
# Calculate the skewness of the 'Weight' column
skewness = response_df['Weight'].skew()

# Print the skewness value
print(f"Skewness of 'Weight': {skewness}")

# Interpret the skewness value
if skewness < -1:
  print("The distribution is highly negatively skewed.")
elif skewness < -0.5:
  print("The distribution is moderately negatively skewed.")
elif skewness < 0:
  print("The distribution is slightly negatively skewed.")
elif skewness == 0:
  print("The distribution is perfectly symmetrical.")
elif skewness < 0.5:
  print("The distribution is slightly positively skewed.")
elif skewness < 1:
  print("The distribution is moderately positively skewed.")
else:
  print("The distribution is highly positively skewed.")
# Out:
# Skewness of 'Weight': 1.2237251927527477
# The distribution is highly positively skewed.

# %% [markdown]
# 4. ¿Cuántos valores faltantes tiene la variable `Weight`? ¿Qué porcentaje representa?

# %%
missing_values_count = response_df['Weight'].isna().sum()
total_values_count = response_df['Weight'].count()
percentage_missing = missing_values_count / total_values_count * 100

print(f"Number of missing values in Weight: {missing_values_count}")
print(f"Percentage of missing values in Weight: {percentage_missing:.2f}%")
# Out:
# Number of missing values in Weight: 20
# Percentage of missing values in Weight: 2.02%

# %% [markdown]
# 5. ¿Tendrán los valores faltantes de `Weight` relación con alguna otra variable? Analízalo considerando las siguientes columnas:
# *   Numéricas: `Age, Number of siblings`
# *   Categóricas: `Gender, Education`
#
# Para ello deberás dividir cada columna en dos grupos: con/sin faltantes en `Weight` y utilizar métodos gráficos y la prueba t para ver si hay diferencias significativas.
#
# **NOTA**. Puedes reutilizar las funciones `Diagnose_MV_Numerical` y `Diagnose_MV_Categorical` definidas en Hands-On-Prep_Missing_Values.zip. Revisa nuevamente cómo utilizarlas.

# %%
import seaborn as sns

# Select relevant columns
df_temp = response_df[['Weight', 'Age', 'Number of siblings', 'Gender', 'Education']]

# Create a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_temp.corr(), annot=True, cmap='coolwarm')
plt.title("Heatmap of correlations between Weight and other variables")
plt.show()
# Out:
# <ipython-input-27-9b861f48967a>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_temp.corr(), annot=True, cmap='coolwarm')

# %%
missing_values = dresponse_df.isnull().sum().div(response_df.shape[0]).mul(100).to_frame().sort_values(by=0, ascending=False)
print(missing_values)
# Out:
#                           0
# Height             1.980198
# Weight             1.980198
# Passive sport      1.485149
# Chemistry          0.990099
# Geography          0.891089
# ...                     ...
# Snakes             0.000000
# Dreams             0.000000
# Internet usage     0.000000
# Eating to survive  0.000000
# Number of friends  0.000000
#
# [150 rows x 1 columns]

# %% [markdown]
# 6. Utiliza una medida de tendencia central para imputar los valores faltantes de `Weight`. ¿Cuál es recomendable y por qué?

# %%
# Calculate the mean of the 'Weight' column
mean_weight = response_df['Weight'].mean()

# Impute the missing values with the mean
response_df['Weight'].fillna(mean_weight, inplace=True)

print("The mean is a good measure of central tendency to impute missing values.")
# Out:
# The mean is a good measure of central tendency to impute missing values.

# %% [markdown]
# 7. ¿Hay valores atípicos de la variable `Weight`? Confírmalo con un gráfico de boxplot. ¿Cuántos son? Almacénalos en un dataframe independiente y elimínalos del conjunto original.

# %%
# Create a boxplot of the 'Weight' column
sns.boxplot(x=response_df["Weight"])
plt.show()

# Identify outlier values based on the interquartile range (IQR) method
Q1 = response_df["Weight"].quantile(0.25)
Q3 = response_df["Weight"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Select rows with outlier values
outlier_rows = response_df[(response_df["Weight"] < lower_bound) | (response_df["Weight"] > upper_bound)]

# Count the number of outlier values
outlier_count = len(outlier_rows)
outlier_df = outlier_rows.copy()

# Remove outlier rows from the original dataframe
response_df = response_df[~((response_df["Weight"] < lower_bound) | (response_df["Weight"] > upper_bound))]
print(f"Number of outlier values in 'Weight': {outlier_count}")
# Out:
# Number of outlier values in 'Weight': 10

# %% [markdown]
# 8. Repite el mismo proceso de valores atípicos con la variable `Height`.

# %%
# Create a boxplot of the 'Height' column
sns.boxplot(x=response_df["Height"])
plt.show()

# Identify outlier values based on the interquartile range (IQR) method
Q1 = response_df["Height"].quantile(0.25)
Q3 = response_df["Height"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Select rows with outlier values
outlier_rows = response_df[(response_df["Height"] < lower_bound) | (response_df["Height"] > upper_bound)]

# Count the number of outlier values
outlier_count = len(outlier_rows)
outlier_df = outlier_rows.copy()

# Remove outlier rows from the original dataframe
response_df = response_df[~((response_df["Height"] < lower_bound) | (response_df["Height"] > upper_bound))]
print(f"Number of outlier values in 'Height': {outlier_count}")
# Out:
# Number of outlier values in 'Height': 5

# %% [markdown]
# 9. ¿Hay encuestados que sean atípicos según su índice de masa corporal (`BMI`)? El `BMI` puede ser calculado usando la siguiente fórmula:
#
# `BMI = Weight / Height ^ 2`
#
# **NOTA**. El peso tiene que estar en kilogramos y la altura en metros, pero en el conjunto la altura se ha registrado en centímetros, por lo que deberás convertirla a metros.

# %%
response_df['Height'] = response_df['Height'] / 100
response_df['BMI'] = response_df['Weight'] / (response_df['Height'] ** 2)
print(response_df['BMI'])

# %%
# Create boxplots for BMI grouped by Gender
sns.boxplot(x="Gender", y="BMI", data=response_df)
plt.title("BMI distribution by Gender")
plt.show()

# Create boxplots for BMI grouped by Education
sns.boxplot(x="Education", y="BMI", data=response_df)
plt.title("BMI distribution by Education")
plt.show()

# Create boxplots for BMI grouped by Religion
sns.boxplot(x="Religion", y="BMI", data=response_df)
plt.title("BMI distribution by Religion")
plt.show()

# Create boxplots for BMI grouped by Smoking
sns.boxplot(x="Smoking", y="BMI", data=response_df)
plt.title("BMI distribution by Smoking")
plt.show()

# Create boxplots for BMI grouped by Gender and Education
sns.boxplot(x="Gender", y="BMI", hue="Education", data=response_df)
plt.title("BMI distribution by Gender and Education")
plt.show()

# Create boxplots for BMI grouped by Gender and Religion
sns.boxplot(x="Gender", y="BMI", hue="Religion", data=response_df)
plt.title("BMI distribution by Gender and Religion")
plt.show()


# Create boxplots for BMI grouped by Gender and Smoking
sns.boxplot(x="Gender", y="BMI", hue="Smoking", data=response_df)
plt.title("BMI distribution by Gender and Smoking")
plt.show()


# Create boxplots for BMI grouped by Education and Religion
sns.boxplot(x="Education", y="BMI", hue="Religion", data=response_df)
plt.title("BMI distribution by Education and Religion")
plt.show()

# %% [markdown]
# 10. Utiliza boxplots para visualizar la distribución del `BMI` según cada una de las variables categóricas de texto. Comenta un hallazgo que llame tu atención.

# %%
print("I found the correlation with education very interesting, especially with the doctorate level. ")
# Out:
# I found the correlation with education very interesting, especially with the doctorate level.
