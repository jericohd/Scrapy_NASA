# %% [markdown]
# <a href="https://colab.research.google.com/github/jericohd/Scrapy_NASA/blob/main/Actividad_2_Pandas_AnalysisA01795534.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 2**
# Pandas para el análisis de datos en Python
#
# ---

# %% [markdown]
# *   NOMBRE: Hernan dez Diaz Irving Jerico
# *   MATRÍCULA: A01795534

# %% [markdown]
# ---

# %% [markdown]
# En esta actividad usarás el archivo de datos `LaqnData.csv`. Cada fila de este conjunto de datos muestra un registro de medición, por hora, de uno de los siguientes cinco contaminantes del aire:
#
# *   `NO` (óxido nítrico)
# *   `NO2` (dióxido de nitrógeno)
# *   `NOX` (óxidos nitrosos)
# *   `PM10` (partículas suspendidas con un diámetro aerodinámico igual o menor a 10 micrómetros)
# *   `PM2.5` (partículas suspendidas con un diámetro aerodinámico igual o menor a 2.5 micrómetros)
#
# Los datos se recopilaron en una ubicación de Londres durante todo el año 2017.
#
# **NOTA IMPORTANTE:** Asegúrate de responder *explícitamente* todos los cuestionamientos.

# %% [markdown]
# 1.	Descarga el archivo: `LaqnData.csv` y guarda, en un dataframe (`air_df`), todos sus registros.
# *   Observa la estructura y contenido del dataframe con los atributos y métodos estudiados (`shape`, `columns`, `head()`, `tail()`, `dtypes`)
# *   Calcula el porcentaje de valores faltantes por columna.

# %%
import pandas as pd

# %%
url ="/content/Laqn_Data.csv"
air_df=pd.read_csv(url)

# %%
air_df.shape
# Out:
# (43800, 6)

# %%
air_df.columns
# Out:
# Index(['Site', 'Species', 'ReadingDateTime', 'Value', 'Units',
#        'Provisional or Ratified'],
#       dtype='object')

# %%
air_df.head(10)
# Out:
#   Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 0  CT3      NO  01/01/2017 00:00    3.5  ug m-3                       R
# 1  CT3      NO  01/01/2017 01:00    3.6  ug m-3                       R
# 2  CT3      NO  01/01/2017 02:00    2.2  ug m-3                       R
# 3  CT3      NO  01/01/2017 03:00    2.1  ug m-3                       R
# 4  CT3      NO  01/01/2017 04:00    3.3  ug m-3                       R
# 5  CT3      NO  01/01/2017 05:00    2.1  ug m-3                       R
# 6  CT3      NO  01/01/2017 06:00    4.4  ug m-3                       R
# 7  CT3      NO  01/01/2017 07:00    5.1  ug m-3                       R
# 8  CT3      NO  01/01/2017 08:00    7.4  ug m-3                       R
# 9  CT3      NO  01/01/2017 09:00    6.5  ug m-3                       R

# %%
air_df.tail(10)
# Out:
#       Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 43790  CT3   PM2.5  31/12/2017 14:00    8.0  ug m-3                       R
# 43791  CT3   PM2.5  31/12/2017 15:00    2.0  ug m-3                       R
# 43792  CT3   PM2.5  31/12/2017 16:00    2.0  ug m-3                       R
# 43793  CT3   PM2.5  31/12/2017 17:00    4.0  ug m-3                       R
# 43794  CT3   PM2.5  31/12/2017 18:00    5.0  ug m-3                       R
# 43795  CT3   PM2.5  31/12/2017 19:00   -2.0  ug m-3                       R
# 43796  CT3   PM2.5  31/12/2017 20:00    6.0  ug m-3                       R
# 43797  CT3   PM2.5  31/12/2017 21:00    5.0  ug m-3                       R
# 43798  CT3   PM2.5  31/12/2017 22:00    5.0  ug m-3                       R
# 43799  CT3   PM2.5  31/12/2017 23:00    6.0  ug m-3                       R

# %%
air_df.dtypes
# Out:
# Site                        object
# Species                     object
# ReadingDateTime             object
# Value                      float64
# Units                       object
# Provisional or Ratified     object
# dtype: object

# %%
na_percent = ((air_df.isnull().sum() / len(air_df))*100).sort_values(ascending = False)
print(na_percent)
# Out:
# Value                      7.374429
# Site                       0.000000
# Species                    0.000000
# ReadingDateTime            0.000000
# Units                      0.000000
# Provisional or Ratified    0.000000
# dtype: float64

# %% [markdown]
# 2.	Obtén la cantidad de valores únicos por columna (`nunique()`) para responder:
#
#
# *   ¿Cuántas mediciones se hicieron?
# *   ¿Cuántos contaminantes del aire (`Species`) se analizaron?
# 5
#
#
# *   ¿Qué columnas no agregan ningún valor informativo porque el mismo valor en todo el conjunto de datos? Elimínalas del dataframe.
# site, unites y Provisional or Ratified ya que son pocas unidades
#
#
# *   La columna `Units` tampoco posee valor informativo. Verifícalo con la función `unique()` y elimínala del dataframe.

# %%
air_df.nunique()
# Out:
# Site                          1
# Species                       5
# ReadingDateTime            8760
# Value                      1847
# Units                         3
# Provisional or Ratified       1
# dtype: int64

# %%
air_df.drop(columns=['Units'])
# Out:
#       Site Species   ReadingDateTime  Value Provisional or Ratified
# 0      CT3      NO  01/01/2017 00:00    3.5                       R
# 1      CT3      NO  01/01/2017 01:00    3.6                       R
# 2      CT3      NO  01/01/2017 02:00    2.2                       R
# 3      CT3      NO  01/01/2017 03:00    2.1                       R
# 4      CT3      NO  01/01/2017 04:00    3.3                       R
# ...    ...     ...               ...    ...                     ...
# 43795  CT3   PM2.5  31/12/2017 19:00   -2.0                       R
# 43796  CT3   PM2.5  31/12/2017 20:00    6.0                       R
# 43797  CT3   PM2.5  31/12/2017 21:00    5.0                       R
# 43798  CT3   PM2.5  31/12/2017 22:00    5.0                       R
# 43799  CT3   PM2.5  31/12/2017 23:00    6.0                       R
#
# [43800 rows x 5 columns]

# %% [markdown]
# 3.	Realiza el conteo de valores por categoría (`value_counts()`) para la columna `Species` y determina si las lecturas de cada contaminante coincide con el total de mediciones.

# %%
air_df.value_counts('Species')
# Out:
# Species
# NO       8760
# NO2      8760
# NOX      8760
# PM10     8760
# PM2.5    8760
# dtype: int64

# %% [markdown]
# 4.	Utiliza la función `groupby()` para determinar el promedio del valor por contaminante.

# %%
air_df.groupby(['Species']).mean()
# Out:
# <ipython-input-20-b69c9a5ecc48>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   air_df.groupby(['Species']).mean()
#              Value
# Species
# NO       15.045115
# NO2      38.010185
# NOX      61.078661
# PM10     22.551704
# PM2.5    14.999831

# %% [markdown]
# 5.	El conjunto de datos está en un formato largo. Aplique la función apropiada para cambiarlo al formato ancho (`ReadingDateTime` como índice y cada contaminante en una columna). Nombre el dataframe resultante como `pvt_df`.

# %%
pvt_df = air_df.set_index('ReadingDateTime')
pvt_df.head(5)
# Out:
#                  Site Species  Value   Units Provisional or Ratified
# ReadingDateTime
# 01/01/2017 00:00  CT3      NO    3.5  ug m-3                       R
# 01/01/2017 01:00  CT3      NO    3.6  ug m-3                       R
# 01/01/2017 02:00  CT3      NO    2.2  ug m-3                       R
# 01/01/2017 03:00  CT3      NO    2.1  ug m-3                       R
# 01/01/2017 04:00  CT3      NO    3.3  ug m-3                       R

# %% [markdown]
# 6.	A través de la función `describe()` responde:
#
# *   ¿Cuál es el mayor valor de `NO2` registrado? ¿A qué día pertenece?
# *   ¿Cuál es el menor valor de `PM10` registrado?¿A qué día pertenece?
# *   ¿Cuál es la mediana del `NO`? ¿Cómo se interpreta?
# *   ¿Cuál es el primer cuartil de `PM2.5`? ¿Qué significa?

# %%
pvt_df.describe()
# Out:
#               Value
# count  40570.000000
# mean      31.368602
# std       35.343362
# min       -8.000000
# 25%       11.000000
# 50%       22.100000
# 75%       40.900000
# max      734.299990
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_17['Value'].plot(kind='hist', bins=20, title='Value')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18['Value'].plot(kind='line', figsize=(8, 4), title='Value')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# 7.	Dibuja un histograma para cada columna de `pvt_df`. ¿Qué contaminante tiene mayor variabilidad?

# %%
histogram = pvt_df.plot.hist()

# %%
histogram = pvt_df.plot.hist('Site')
histogram = pvt_df.plot.hist('Species')
histogram = pvt_df.plot.hist('Provisional or Ratified')

# %%
#histogram = pvt_df.plot.hist('Value')
#histogram = pvt_df.plot.hist('Units')
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-43-663a925873ba> in <cell line: 1>()
# ----> 1 histogram = pvt_df.plot.hist('Value')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwargs)
#    1372             >>> ax = df.plot.hist(column=["age"], by="gender", figsize=(10, 8))
#    1373         """
# -> 1374         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1375
#    1376     def kde(self, bw_method=None, ind=None, **kwargs) -> PlotAccessor:
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# ...

# %% [markdown]
# 8.	Ejecuta el siguiente código y comenta qué hace cada línea:

# %%
datetime_df = air_df.ReadingDateTime.str.split(' ',expand=True)
datetime_df.columns = ['Date','Time']
datetime_df
date_df = datetime_df.Date.str.split('/',expand=True)
date_df.columns = ['Day','Month','Year']
date_df
air_df = air_df.join(date_df).join(datetime_df.Time).drop(columns=['ReadingDateTime','Year'])
air_df = air_df.set_index(['Month','Day','Time','Species'])
air_df
# Out:
#                         Site  Value   Units Provisional or Ratified
# Month Day Time  Species
# 01    01  00:00 NO       CT3    3.5  ug m-3                       R
#           01:00 NO       CT3    3.6  ug m-3                       R
#           02:00 NO       CT3    2.2  ug m-3                       R
#           03:00 NO       CT3    2.1  ug m-3                       R
#           04:00 NO       CT3    3.3  ug m-3                       R
# ...                      ...    ...     ...                     ...
# 12    31  19:00 PM2.5    CT3   -2.0  ug m-3                       R
#           20:00 PM2.5    CT3    6.0  ug m-3                       R
#           21:00 PM2.5    CT3    5.0  ug m-3                       R
#           22:00 PM2.5    CT3    5.0  ug m-3                       R
#           23:00 PM2.5    CT3    6.0  ug m-3                       R
#
# [43800 rows x 4 columns]

# %% [markdown]
#  8. lo que hace este fragmento de codigo es cambiar 'ReadingDataTime' a un formato mas legible por mes dia y año para hacerlo su index junto a 'Spices'

# %% [markdown]
# 9. Ejecuta la siguiente instrucción y compara su salida con la del código anterior (ejercicio 8). ¿Son iguales?

# %%
air_df.unstack()
# Out:
#                 Site                      Value                          \
# Species           NO  NO2  NOX PM10 PM2.5    NO   NO2   NOX  PM10 PM2.5
# Month Day Time
# 01    01  00:00  CT3  CT3  CT3  CT3   CT3   3.5  30.8  36.2  35.7   NaN
#           01:00  CT3  CT3  CT3  CT3   CT3   3.6  31.5  37.0  28.5   NaN
#           02:00  CT3  CT3  CT3  CT3   CT3   2.2  27.3  30.7  22.7   NaN
#           03:00  CT3  CT3  CT3  CT3   CT3   2.1  23.5  26.8  20.5   NaN
#           04:00  CT3  CT3  CT3  CT3   CT3   3.3  28.0  33.0  22.1   NaN
# ...              ...  ...  ...  ...   ...   ...   ...   ...   ...   ...
# 12    31  19:00  CT3  CT3  CT3  CT3   CT3   0.7  17.5  18.5  16.3  -2.0
#           20:00  CT3  CT3  CT3  CT3   CT3   0.7  17.5  18.6  14.5   6.0
#           21:00  CT3  CT3  CT3  CT3   CT3   0.7  14.1  15.1   8.6   5.0
#           22:00  CT3  CT3  CT3  CT3   CT3   1.1  22.0  23.6  12.5   5.0
#           23:00  CT3  CT3  CT3  CT3   CT3   0.9  19.4  20.7  10.4   6.0
#
# ...

# %% [markdown]
# 10.	Explica cuáles son las diferencias y similitudes entre el par `melt()/pivot()` y el par `stack()/unstack()`. Si tuvieras que elegir una contraparte para `melt()` entre `stack()/unstack()`, ¿cuál elegirías? ¿Por qué?
